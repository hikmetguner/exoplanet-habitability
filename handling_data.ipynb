# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import warnings
import math

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
df = pd.read_csv("data.csv",header=0, index_col=0)
pd.set_option('mode.chained_assignment', None)

# %%
df.head(10)
# Out:
#                        pl_name               hostname pl_letter    hd_name  \
# rowid
# 1                     11 Com b                 11 Com         b  HD 107383
# 2                     11 UMi b                 11 UMi         b  HD 136726
# 3                     14 And b                 14 And         b  HD 221345
# 4                     14 Her b                 14 Her         b  HD 145675
# 5                   16 Cyg B b               16 Cyg B         b  HD 186427
# 6                     17 Sco b                 17 Sco         b        NaN
# 7                     18 Del b                 18 Del         b  HD 199665
# 8      1RXS J160929.1-210524 b  1RXS J160929.1-210524         b        NaN
# 9                     24 Boo b                 24 Boo         b  HD 127243
# 10                    24 Sex b                 24 Sex         b   HD 90043
#
#          hip_name         tic_id                       gaia_id  sy_snum  \
# rowid
# ...

# %%
cols = ['sy_snum', 'sy_pnum', 'sy_mnum', 'pl_orbper', 'pl_orbsmax', 'pl_rade', 'pl_radj', 'pl_bmasse', 'pl_bmassj', 'pl_dens', 'pl_orbeccen', 'pl_insol', 'pl_eqt', 
'pl_orbincl', 'pl_trandep', 'pl_ratdor', 'pl_orbtper', 'pl_orblper', 'st_spectype', 'st_teff', 'st_rad', 'st_mass', 'st_lum', 'st_logg', 'st_age', 'st_dens', 'st_vsin', 'st_rotp', 'st_radv', 'cb_flag', 'sy_bmag', 'sy_vmag', 'sy_jmag', 'sy_hmag', 'sy_kmag', 'sy_umag', 'sy_gmag', 'sy_rmag', 'sy_imag', 'sy_zmag', 'sy_w1mag', 'sy_w2mag', 'sy_w3mag', 'sy_w4mag', 'sy_gaiamag', 'sy_icmag', 'sy_tmag', 'sy_kepmag', 'pl_name', 'hostname', 'sy_dist', 'pl_bmassprov', 'pl_tranmid', 'pl_imppar', 'pl_trandur', 'pl_ratror', 'pl_occdep', 'pl_rvamp', 'pl_projobliq', 'pl_trueobliq']

# %%
df = df[cols]

# %%
df.head()
# Out:
#        sy_snum  sy_pnum  sy_mnum    pl_orbper  pl_orbsmax  pl_rade  pl_radj  \
# rowid
# 1            2        1        0   326.030000    1.290000     12.1     1.08
# 2            1        1        0   516.219970    1.530000     12.3     1.09
# 3            1        1        0   185.840000    0.830000     12.9     1.15
# 4            1        2        0  1765.038901    2.773069     12.6     1.12
# 5            3        1        0   798.500000    1.660000     13.5     1.20
#
#         pl_bmasse  pl_bmassj  pl_dens  ...   sy_dist  pl_bmassprov  \
# rowid                                  ...
# 1      6165.60000   19.40000    19.10  ...   93.1846         Msini
# 2      4684.81420   14.74000    13.80  ...  125.3210         Msini
# 3      1525.50000    4.80000     3.90  ...   75.4392         Msini
# 4      2586.74645    8.13881     7.11  ...   17.9323          Mass
# 5       565.73740    1.78000     1.26  ...   21.1397         Msini
#
# ...

# %%
df.isna().sum().to_frame()
# Out:
#                  0
# sy_snum          0
# sy_pnum          0
# sy_mnum          0
# pl_orbper      191
# pl_orbsmax     286
# pl_rade         17
# pl_radj         18
# pl_bmasse       23
# pl_bmassj       23
# pl_dens        114
# pl_orbeccen    682
# pl_insol      1611
# pl_eqt        1363
# pl_orbincl    1251
# pl_trandep    1455
# pl_ratdor     1384
# pl_orbtper    4315
# pl_orblper    3726
# st_spectype   3375
# st_teff        160
# st_rad         181
# st_mass          4
# st_lum         176
# st_logg        189
# st_age        1103
# st_dens        435
# st_vsin       3407
# st_rotp       4690
# st_radv       3067
# cb_flag          0
# sy_bmag        248
# sy_vmag        159
# sy_jmag        176
# sy_hmag        161
# sy_kmag        155
# sy_umag       4620
# sy_gmag       1945
# sy_rmag       1928
# sy_imag       1981
# sy_zmag       2193
# sy_w1mag       376
# sy_w2mag       375
# sy_w3mag       375
# sy_w4mag       376
# sy_gaiamag     209
# sy_icmag      4924
# ...

# %%
drop = [
"pl_trueobliq",
"pl_occdep",
"pl_projobliq",
"sy_icmag",
"st_rotp",
"sy_umag",
"pl_orbtper",
"pl_orblper",
"st_vsin",
"pl_rvamp",
"st_spectype",
"st_radv",
"sy_zmag",
"sy_imag",
"sy_gmag",
"sy_rmag",
"sy_kepmag",
"pl_insol",
"pl_trandep",
"pl_imppar",
"pl_ratror",
"pl_ratdor",
"pl_eqt",
"pl_trandur",
"pl_orbincl",
"st_age",
"pl_tranmid",
]

# %%
df = df.drop(columns=drop)

# %%
df.isna().sum().to_frame()
# Out:
#                 0
# sy_snum         0
# sy_pnum         0
# sy_mnum         0
# pl_orbper     191
# pl_orbsmax    286
# pl_rade        17
# pl_bmasse      23
# pl_bmassj      23
# pl_dens       114
# pl_orbeccen   682
# st_teff       160
# st_rad        181
# st_mass         4
# st_lum        176
# st_logg       189
# st_dens       435
# cb_flag         0
# sy_bmag       248
# sy_vmag       159
# sy_jmag       176
# sy_hmag       161
# sy_kmag       155
# sy_w1mag      376
# sy_w2mag      375
# sy_w3mag      375
# sy_w4mag      376
# sy_gaiamag    209
# sy_tmag       163
# pl_name         0
# hostname        0
# pl_bmassprov    0

# %%
s = df.set_index('pl_name').isna().groupby('pl_name').sum().sum(axis=1)
for i in df['pl_name']:
    df.loc[df['pl_name'] == i,'empty_col_count'] = s[i]

# %%
df.groupby(['empty_col_count'])['empty_col_count'].count().to_frame()
# Out:
#                  empty_col_count
# empty_col_count
# 0.0                         3914
# 1.0                          609
# 2.0                          273
# 3.0                           41
# 4.0                          153
# 5.0                           56
# 6.0                           12
# 7.0                            9
# 8.0                            9
# 10.0                           6
# 13.0                           1
# 15.0                          11
# 16.0                          14
# 17.0                          18
# 18.0                         114
# 19.0                           3

# %%
temp = df[df['empty_col_count'] < 2]
temp.columns[temp.isna().any()].to_frame()
# Out:
#                        0
# pl_orbper      pl_orbper
# pl_orbsmax    pl_orbsmax
# pl_dens          pl_dens
# pl_orbeccen  pl_orbeccen
# st_dens          st_dens
# sy_bmag          sy_bmag
# sy_gaiamag    sy_gaiamag
